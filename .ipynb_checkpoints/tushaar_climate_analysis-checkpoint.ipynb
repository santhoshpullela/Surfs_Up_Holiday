# %%
# Import the dependencies
import matplotlib
matplotlib.use('nbagg')
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func, desc

import pandas as pd
import numpy as np
import csv
import os
import seaborn as sns
from datetime import datetime as dt, timedelta

# %% [markdown]
# # Step 3 - Climate Analysis and Exploration

# %%
# Create an engine to a SQLite database file called `hawaii.sqlite`
engine = create_engine("sqlite:///hawaii.sqlite", echo = False)

# %% [markdown]
# # Explore Database

# %%
# Get the tables in the Hawaii Database
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurements', 'stations']

# %%
# Get a list of column names and types for Measurements Table
columns = inspector.get_columns('measurements')
for c in columns:
    print(c['name'], c["type"])
# columns
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Get a list of column names and types for Stations Table
columns = inspector.get_columns('stations')
for c in columns:
    print(c['name'], c["type"])
# columns
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %% [markdown]
# # Reflect and Query

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys() # Retrieve the names of the tables in the database
# Out:
# ['measurements', 'stations']

# %%
Measurements = Base.classes.measurements # Map measurements class
Stations = Base.classes.stations # Map stations class

# %%
session = Session(engine)

# %% [markdown]
# # Precipitation Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data.
# Select only the date and prcp values.
# Load the query results into a Pandas DataFrame and set the index to the date column.
# Plot the results using the DataFrame plot method.

# %%
# Retrieve Latest Date
session.query(Measurements.date).order_by(Measurements.date.desc()).first()
# Out:
# ('2017-08-23')

# %%
latest_date = session.query(Measurements.date).order_by(Measurements.date.desc()).first()[0]

# %%
latest_date
# Out:
# '2017-08-23'

# %%
format_latest_date = dt.strptime(latest_date,"%Y-%m-%d")

# %%
format_latest_date
# Out:
# datetime.datetime(2017, 8, 23, 0, 0)

# %%
# Query for retrieving last 12 months of precipitation data
# All precipitation data for last 12 months
sel = [Measurements.date, Measurements.prcp]

initial_date = format_latest_date - timedelta(days=365) # This will be start date from 12 months before final date of 8/23/17


prcp_data = session.query(*sel).\
    filter((Measurements.date >= initial_date)).all()
    
### END SOLUTION
prcp_data[:10]
# Out:
# [('2016-08-24', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-26', 0.0),
#  ('2016-08-27', 0.0),
#  ('2016-08-28', 0.01),
#  ('2016-08-29', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-31', 0.13),
#  ('2016-09-01', 0.0),
#  ('2016-09-02', 0.0)]

# %%
prcp_data_df  = pd.DataFrame(prcp_data,columns=["Precipitation Date", "Precipitation"])

# %%
prcp_data_df.head()
# Out:
#   Precipitation Date  Precipitation
# 0         2016-08-24           0.08
# 1         2016-08-25           0.08
# 2         2016-08-26           0.00
# 3         2016-08-27           0.00
# 4         2016-08-28           0.01

# %%
prcp_data_dict= prcp_data_df.to_dict(orient='records')

# %%
prcp_data_dict
# Out:
# [{'Precipitation': 0.08, 'Precipitation Date': '2016-08-24'},
#  {'Precipitation': 0.08, 'Precipitation Date': '2016-08-25'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-08-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-08-27'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2016-08-28'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-08-29'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-08-30'},
#  {'Precipitation': 0.13, 'Precipitation Date': '2016-08-31'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-01'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-02'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-03'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-09-04'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2016-09-07'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-08'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-09-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-10'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2016-09-11'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-12'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-09-13'},
#  {'Precipitation': 1.32, 'Precipitation Date': '2016-09-14'},
#  {'Precipitation': 0.42, 'Precipitation Date': '2016-09-15'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2016-09-16'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2016-09-17'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-19'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-20'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-21'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-09-22'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-23'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-24'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-25'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2016-09-26'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-09-27'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-28'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-29'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-30'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-01'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-02'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-03'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-04'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-05'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-06'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-07'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-08'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-10'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-11'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-12'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-13'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-14'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-15'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-16'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2016-10-17'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-19'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-20'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2016-10-21'},
#  {'Precipitation': 0.15, 'Precipitation Date': '2016-10-22'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2016-10-23'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-24'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-10-25'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-27'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-28'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-29'},
#  {'Precipitation': 0.24, 'Precipitation Date': '2016-10-30'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-10-31'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-01'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-02'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-03'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-04'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-05'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-06'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-07'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2016-11-08'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-10'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-11'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-12'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-13'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-14'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-15'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-16'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-17'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-18'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-11-19'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2016-11-20'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2016-11-21'},
#  {'Precipitation': 0.13, 'Precipitation Date': '2016-11-22'},
#  {'Precipitation': 0.14, 'Precipitation Date': '2016-11-23'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2016-11-24'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2016-11-25'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2016-11-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-27'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2016-11-28'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-29'},
#  {'Precipitation': 0.14, 'Precipitation Date': '2016-11-30'},
#  {'Precipitation': 0.12, 'Precipitation Date': '2016-12-01'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-12-02'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-12-03'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-12
},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-12-06'},
#  {'Precipitation': 0.17, 'Precipitation Date': '2016-12-07'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-12-08'},
#  {'Precipitation': 0.34, 'Precipitation Date': '2016-12-09'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-12-10'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-12-11'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2016-12-12'},
#  {'Precipitation': 0.1, 'Precipitation Date': '2016-12-13'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2016-12-14'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-12-15'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2016-12-16'},
#  {'Precipitation': 0.11, 'Precipitation Date': '2016-12-17'},
#  {'Precipitation': 0.29, 'Precipitation Date': '2016-12-18'},
#  {'Precipitation': 0.21, 'Precipitation Date': '2016-12-19'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-12-20'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-12-21'},
#  {'Precipitation': 0.17, 'Precipitation Date': '2016-12-22'},
#  {'Precipitation': 0.1, 'Precipitation Date': '2016-12-23'},
#  {'Precipitation': 0.14, 'Precipitation Date': '2016-12-24'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-12-25'},
#  {'Precipitation': 0.26, 'Precipitation Date': '2016-12-26'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-12-27'},
#  {'Precipitation': 0.09, 'Precipitation Date': '2016-12-28'},
#  {'Precipitation': 0.18, 'Precipitation Date': '2016-12-29'},
#  {'Precipitation': 0.21, 'Precipitation Date': '2016-12-30'},
#  {'Precipitation': 0.62, 'Precipitation Date': '2016-12-31'},
#  {'Precipitation': 0.29, 'Precipitation Date': '2017-01-01'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-02'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-03'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-04'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-05'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-06'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2017-01-07'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-08'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-10'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-11'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-12'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-13'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-14'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-15'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-16'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-17'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-19'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-20'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2017-01-21'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-01-22'},
#  {'Precipitation': 0.08, 'Precipitation Date': '2017-01-23'},
#  {'Precipitation': 0.15, 'Precipitation Date': '2017-01-24'},
#  {'Precipitation': 0.12, 'Precipitation Date': '2017-01-25'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-27'},
#  {'Precipitation': 0.14, 'Precipitation Date': '2017-01-28'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-29'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-30'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-31'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-01'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-02'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-03'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-04'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-05'},
#  {'Precipitation': 0.16, 'Precipitation Date': '2017-02-06'},
#  {'Precipitation': 1.08, 'Precipitation Date': '2017-02-07'},
#  {'Precipitation': 1.08, 'Precipitation Date': '2017-02-08'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-02-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-10'},
#  {'Precipitation': 1.0, 'Precipitation Date': '2017-02-11'},
#  {'Precipitation': 1.07, 'Precipitation Date': '2017-02-12'},
#  {'Precipitation': 2.9, 'Precipitation Date': '2017-02-13'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-14'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-15'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-16'},
#  {'Precipitation': 0.8, 'Precipitation Date': '2017-02-17'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-19'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-20'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-21'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2017-02-22'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-23'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-24'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-25'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-27'},
#  {'Precipitation': 0.16, 'Precipitation Date': '2017-02-28'},
#  {'Precipitation': 2.2, 'Precipitation Date': '2017-03-01'},
#  {'Precipitation': 1.45, 'Precipitation Date': '2017-03-02'},
#  {'Precipitation': 0.54, 'Precipitation Date': '2017-03-03'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-04'},
#  {'Precipitation': 0.1, 'Precipitation Date': '2017-03-05'},
#  {'Precipitation': 0.51, 'Precipitation Date': '2017-03-06'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-07'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-08'},
#  {'Precipitation': 0.8, 'Precipitation Date': '2017-03-09'},
#  {'Precipitation': 0.13, 'Precipitation Date': '2017-03-10'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-03-11'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-12'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-13'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-14'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-15'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-16'},
#  {'Precipitation': 0.19, 'Precipitation Date': '2017-03-17'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-19'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-20'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-21'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-22'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-23'},
#  {'Precipitation': 0.6, 'Precipitation Date': '2017-03-24'},
#  {'Precipitation': 0.13, 'Precipitation Date': '2017-03-25'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-27'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-03-28'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-29'},
#  {'Precipitation': 0.08, 'Precipitation Date': '2017-03-30'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-31'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-01'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-02'},
#  {'Precipitation': 0.08, 'Precipitation Date': '2017-04-03'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2017-04-04'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2017-04-05'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-06'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-07'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-08'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-09'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-04-10'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-04-11'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-04-12'},
#  {'Precipitation': 0.27, 'Precipitation Date': '2017-04-13'},
#  {'Precipitation': 0.69, 'Precipitation Date': '2017-04-14'},
#  {'Precipitation': 0.45, 'Precipitation Date': '2017-04-15'},
#  {'Precipitation': 0.49, 'Precipitation Date': '2017-04-16'},
#  {'Precipitation': 0.41, 'Precipitation Date': '2017-04-17'},
#  {'Precipitation': 0.08, 'Precipitation Date': '2017-04-18'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-04-19'},
#  {'Precipitation': 0.33, 'Precipitation Date': '2017-04-20'},
#  {'Precipitation': 1.16, 'Precipitation Date': '2017-04-21'},
#  {'Precipitation': 1.01, 'Precipitation Date': '2017-04-22'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-04-23'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-24'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-25'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-26'},
#  {'Precipitation': 0.1, 'Precipitation Date': '2017-04-27'},
#  {'Precipitation': 2.6, 'Precipitation Date': '2017-04-28'},
#  {'Precipitation': 0.35, 'Precipitation Date': '2017-04-29'},
#  {'Precipitation': 1.21, 'Precipitation Date': '2017-04-30'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2017-05-01'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-05-02'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-05-03'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-04'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-05'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-06'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2017-05-07'},
#  {'Precipitation': 0.22, 'Precipitation Date': '2017-05-08'},
#  {'Precipitation': 1.62, 'Precipitation Date': '2017-05-09'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2017-05-10'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-05-11'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2017-05-12'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-05-13'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2017-05-14'},
#  {'Precipitation': 0.08, 'Precipitation Date': '2017-05-15'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-05-16'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-05-17'},
#  {'Precipitation': 0.09, 'Precipitation Date': '2017-05-18'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-05-19'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-20'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-21'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-22'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-05-23'},
#  {'Precipitation': 0.58, 'Precipitation Date': '2017-05-24'},
#  {'Precipitation': 0.37, 'Precipitation Date': '2017-05-25'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-05-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-27'},
#  {'Precipitation': 0.29, 'Precipitation Date': '2017-05-28'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-05-29'},
#  {'Precipitation': 0.2, 'Precipitation Date': '2017-05-30'},
#  {'Precipitation': 0.1, 'Precipitation Date': '2017-05-31'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-06-01'},
#  {'Precipitation': 0.1, 'Precipitation Date': '2017-06-02'},
#  {'Precipitation': 0.2, 'Precipitation Date': '2017-06-03'},
#  {'Precipitation': 0.15, 'Precipitation Date': '2017-06-04'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-06-05'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-06-06'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-06-07'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-06-08'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-06-09'},
#  {'Precipitation': 0.21, 'Precipitation Date': '2017-06-10'},
#  {'Precipitation': 0.24, 'Precipitation Date': '2017-06-11'},
#  {'Precipitation': 0.19, 'Precipitation Date': '2017-06-12'},
#  {'Precipitation': 0.36, 'Precipitation Date': '2017-06-13'},
#  {'Precipitation': 0.27, 'Precipitation Date': '2017-06-14'},
#  {'Precipitation': 0.17, 'Precipitation Date': '2017-06-15'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-06-16'},
#  {'Precipitation': 0.35, 'Precipitation Date': '2017-06-17'},
#  {'Precipitation': 0.25, 'Precipitation Date': '2017-06-18'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2017-06-19'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2017-06-20'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-06-21'},
#  {'Precipitation': 0.1, 'Precipitation Date': '2017-06-22'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-06-23'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-06-24'},
#  {'Precipitation': 0.08, 'Precipitation Date': '2017-06-25'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-06-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-06-27'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-06-28'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-06-29'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2017-06-30'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2017-07-01'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2017-07-02'},
#  {'Precipitation': 0.13, 'Precipitation Date': '2017-07-03'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-07-04'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-05'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-06'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-07-07'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-07-08'},
#  {'Precipitation': 0.09, 'Precipitation Date': '2017-07-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-10'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-07-11'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-07-12'},
#  {'Precipitation': 0.33, 'Precipitation Date': '2017-07-13'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2017-07-14'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-07-15'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2017-07-16'},
#  {'Precipitation': 0.12, 'Precipitation Date': '2017-07-17'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-07-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-19'},
#  {'Precipitation': 0.12, 'Precipitation Date': '2017-07-20'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-21'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2017-07-22'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2017-07-23'},
#  {'Precipitation': 0.58, 'Precipitation Date': '2017-07-24'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-07-25'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2017-07-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-27'},
#  {'Precipitation': 0.13, 'Precipitation Date': '2017-07-28'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2017-07-29'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-30'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-31'},
#  {'Precipitation': 2.28, 'Precipitation Date': '2016-08-24'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-08-25'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-08-26'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-08-27'},
#  {'Precipitation': 0.14, 'Precipitation Date': '2016-08-28'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2016-08-29'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-01'},
#  {'Precipitation': 0.19, 'Precipitation Date': '2016-09-02'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2016-09-06'},
#  {'Precipitation': 0.23, 'Precipitation Date': '2016-09-07'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2016-09-08'},
#  {'Precipitation': 0.29, 'Precipitation Date': '2016-09-09'},
#  {'Precipitation': 0.32, 'Precipitation Date': '2016-09-13'},
#  {'Precipitation': 1.84, 'Precipitation Date': '2016-09-14'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2016-09-15'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2016-09-16'},
#  {'Precipitation': 0.25, 'Precipitation Date': '2016-09-20'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-09-21'},
#  {'Precipitation': 0.17, 'Precipitation Date': '2016-09-22'},
#  {'Precipitation': 0.15, 'Precipitation Date': '2016-09-23'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-24'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-25'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-09-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-27'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-28'},
#  {'Precipitation': 0.2, 'Precipitation Date': '2016-09-29'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2016-09-30'},
#  {'Precipitation': 0.08, 'Precipitation Date': '2016-10-01'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-10-02'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-10-03'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-04'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-05'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-06'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-07'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2016-10-11'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-12'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-10-13'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-14'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-10-15'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-10-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-19'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2016-10-20'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-10-21'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2016-10-24'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-25'},
#  {'Precipitation': 0.2, 'Precipitation Date': '2016-10-27'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2016-10-28'},
#  {'Precipitation': 0.26, 'Precipitation Date': '2016-10-29'},
#  {'Precipitation': 0.14, 'Precipitation Date': '2016-10-30'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-10-31'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-01'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-02'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-03'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-04'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-05'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-06'},
#  {'Precipitation': 0.13, 'Precipitation Date': '2016-11-07'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-11-08'},
#  {'Precipitation': 0.17, 'Precipitation Date': '2016-11-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-10'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-11'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-12'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-13'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2016-11-14'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-15'},
#  {'Precipitation': 0.18, 'Precipitation Date': '2016-11-16'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-17'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-11-26'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-11-27'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-28'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2016-11-29'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-11-30'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2016-12-01'},
#  {'Precipitation': 0.4, 'Precipitation Date': '2016-12-02'},
#  {'Precipitation': 0.26, 'Precipitation Date': '2016-12-03'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-12-04'},
#  {'Precipitation': 0.2, 'Precipitation Date': '2016-12-05'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-12-08'},
#  {'Precipitation': 0.26, 'Precipitation Date': '2016-12-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-12-10'},
#  {'Precipitation': 0.34, 'Precipitation Date': '2016-12-13'},
#  {'Precipitation': 0.12, 'Precipitation Date': '2016-12-14'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2016-12-15'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-12-16'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-12-17'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2016-12-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-12-19'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-12-20'},
#  {'Precipitation': 0.09, 'Precipitation Date': '2016-12-21'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2016-12-22'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2016-12-23'},
#  {'Precipitation': 0.13, 'Precipitation Date': '2016-12-24'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-12-27'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2016-12-28'},
#  {'Precipitation': 0.56, 'Precipitation Date': '2016-12-29'},
#  {'Precipitation': 0.29, 'Precipitation Date': '2016-12-30'},
#  {'Precipitation': 0.36, 'Precipitation Date': '2016-12-31'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-01'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-01-02'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-03'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-04'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-05'},
#  {'Precipitation': 0.59, 'Precipitation Date': '2017-01-06'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-07'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-01-08'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-10'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-11'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-14'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-17'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-19'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-20'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-01-21'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-01-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-27'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-28'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-31'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-01'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-02'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-03'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2017-02-06'},
#  {'Precipitation': 0.9, 'Precipitation Date': '2017-02-07'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-08'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-10'},
#  {'Precipitation': 2.39, 'Precipitation Date': '2017-02-11'},
#  {'Precipitation': 1.91, 'Precipitation Date': '2017-02-12'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-13'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-14'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-15'},
#  {'Precipitation': 0.62, 'Precipitation Date': '2017-02-16'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2017-02-17'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-21'},
#  {'Precipitation': 0.11, 'Precipitation Date': '2017-02-22'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-23'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-24'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-27'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2017-02-28'},
#  {'Precipitation': 1.12, 'Precipitation Date': '2017-03-01'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-07'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-08'},
#  {'Precipitation': 0.5, 'Precipitation Date': '2017-03-09'},
#  {'Precipitation': 0.13, 'Precipitation Date': '2017-03-10'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-13'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-14'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2017-03-17'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-21'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-22'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-23'},
#  {'Precipitation': 0.15, 'Precipitation Date': '2017-03-24'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-28'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-03-29'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-03-30'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-03-31'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-01'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-02'},
#  {'Precipitation': 0.09, 'Precipitation Date': '2017-04-03'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-04'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2017-04-05'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-06'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-07'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-10'},
#  {'Precipitation': 0.16, 'Precipitation Date': '2017-04-11'},
#  {'Precipitation': 0.29, 'Precipitation Date': '2017-04-12'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-13'},
#  {'Precipitation': 0.29, 'Precipitation Date': '2017-04-14'},
#  {'Precipitation': 0.12, 'Precipitation Date': '2017-04-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-19'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-20'},
#  {'Precipitation': 1.05, 'Precipitation Date': '2017-04-21'},
#  {'Precipitation': 0.7, 'Precipitation Date': '2017-04-22'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-04-25'},
#  {'Precipitation': 0.14, 'Precipitation Date': '2017-04-26'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-04-27'},
#  {'Precipitation': 0.09, 'Precipitation Date': '2017-04-28'},
#  {'Precipitation': 0.95, 'Precipitation Date': '2017-04-29'},
#  {'Precipitation': 1.17, 'Precipitation Date': '2017-04-30'},
#  {'Precipitation': 0.03, 'Precipitation Date': '2017-05-01'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-05-02'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-05-03'},
#  {'Precipitation': 0.08, 'Precipitation Date': '2017-05-04'},
#  {'Precipitation': 0.28, 'Precipitation Date': '2017-05-05'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2017-05-06'},
#  {'Precipitation': 0.95, 'Precipitation Date': '2017-05-08'},
#  {'Precipitation': 0.52, 'Precipitation Date': '2017-05-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-10'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2017-05-16'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-17'},
#  {'Precipitation': 0.16, 'Precipitation Date': '2017-05-18'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-05-19'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-05-20'},
#  {'Precipitation': 0.11, 'Precipitation Date': '2017-05-23'},
#  {'Precipitation': 0.1, 'Precipitation Date': '2017-05-24'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2017-05-25'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-27'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-05-28'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-29'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2017-05-30'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-05-31'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-06-01'},
#  {'Precipitation': 0.15, 'Precipitation Date': '2017-06-02'},
#  {'Precipitation': 0.16, 'Precipitation Date': '2017-06-03'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2017-06-04'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-06-05'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-06-06'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-06-07'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-06-08'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-06-09'},
#  {'Precipitation': 0.53, 'Precipitation Date': '2017-06-10'},
#  {'Precipitation': 0.14, 'Precipitation Date': '2017-06-11'},
#  {'Precipitation': 0.35, 'Precipitation Date': '2017-06-12'},
#  {'Precipitation': 0.1, 'Precipitation Date': '2017-06-13'},
#  {'Precipitation': 0.21, 'Precipitation Date': '2017-06-14'},
#  {'Precipitation': 0.3, 'Precipitation Date': '2017-06-15'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-06-16'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-06-17'},
#  {'Precipitation': 0.18, 'Precipitation Date': '2017-06-18'},
#  {'Precipitation': 0.19, 'Precipitation Date': '2017-06-19'},
#  {'Precipitation': 0.17, 'Precipitation Date': '2017-06-20'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-06-30'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2017-07-08'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-10'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-11'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-07-12'},
#  {'Precipitation': 0.3, 'Precipitation Date': '2017-07-13'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-14'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-07-15'},
#  {'Precipitation': 0.12, 'Precipitation Date': '2017-07-16'},
#  {'Precipitation': 0.16, 'Precipitation Date': '2017-07-17'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-18'},
#  {'Precipitation': 0.09, 'Precipitation Date': '2017-07-19'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-20'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-21'},
#  {'Precipitation': 0.12, 'Precipitation Date': '2017-07-22'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2017-07-23'},
#  {'Precipitation': 1.19, 'Precipitation Date': '2017-07-24'},
#  {'Precipitation': 0.12, 'Precipitation Date': '2017-07-25'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-07-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-07-27'},
#  {'Precipitation': 0.14, 'Precipitation Date': '2017-07-28'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-07-29'},
#  {'Precipitation': 0.12, 'Precipitation Date': '2017-08-01'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2017-08-02'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-08-03'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2017-08-04'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-08-06'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-08-07'},
#  {'Precipitation': 0.1, 'Precipitation Date': '2017-08-08'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-08-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-08-10'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-08-11'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-08-14'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-08-15'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-08-16'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-08-17'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-08-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-08-19'},
#  {'Precipitation': 0.01, 'Precipitation Date': '2017-08-20'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2017-08-21'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-08-23'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-08-25'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2016-08-26'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-08-30'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-16'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-20'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2016-09-22'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-23'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-09-28'},
#  {'Precipitation': 0.04, 'Precipitation Date': '2016-09-29'},
#  {'Precipitation': 0.07, 'Precipitation Date': '2016-10-06'},
#  {'Precipitation': 0.4, 'Precipitation Date': '2016-10-25'},
#  {'Precipitation': 0.2, 'Precipitation Date': '2016-10-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2016-11-09'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-11-14'},
#  {'Precipitation': 0.27, 'Precipitation Date': '2016-12-08'},
#  {'Precipitation': 0.02, 'Precipitation Date': '2016-12-12'},
#  {'Precipitation': 0.06, 'Precipitation Date': '2016-12-21'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-17'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-18'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-26'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-27'},
#  {'Precipitation': 0.05, 'Precipitation Date': '2017-01-30'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-01-31'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-01'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-02'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-03'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-07'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-08'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-09'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-10'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-14'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-17'},
#  {'Precipitation': 0.17, 'Precipitation Date': '2017-02-22'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-23'},
#  {'Precipitation': 0.0, 'Precipitation Date': '2017-02-24'},
#  {'Precipitation': 2.4, 'Precipitation Date': '2017-03-01'},
#  ...]

# %%
# Create the Dataframe for storing the SQL query results for last 12 months of preceipitation data
prcp_df = pd.DataFrame(prcp_data, columns=['Date', 'Precipitation'])
prcp_df.set_index('Date', inplace=True) # Set the index by date

# %%
# Get the count of total number of records in the dataframe
prcp_df.count()
# Out:
# Precipitation    2015
# dtype: int64

# %%
prcp_df.head() # Display the top 5 records of the dataframe
# Out:
#             Precipitation
# Date
# 2016-08-24           0.08
# 2016-08-25           0.08
# 2016-08-26           0.00
# 2016-08-27           0.00
# 2016-08-28           0.01

# %% [markdown]
# # Precipitation Analysis Plot

# %%
# Create the plot
prcp_df.plot()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Summary Statistics for Precipitation Data

# %%
#Use Pandas to print the summary statistics for the precipitation data.
prcp_df.describe()
# Out:
#        Precipitation
# count    2015.000000
# mean        0.176462
# std         0.460288
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
prcp_df.dtypes
# Out:
# Precipitation    float64
# dtype: object

# %% [markdown]
# # Station Analysis

# %%
# Station Analysis


# Design a query to calculate the total number of stations.
# Design a query to find the most active stations.
    # List the stations and observation counts in descending order
    # Which station has the highest number of observations?
# Design a query to retrieve the last 12 months of temperature observation data (tobs).
    # Filter by the station with the highest number of observations.
    # Plot the results as a histogram with bins=12.

# %%
# Return a json list of stations from the dataset

# %%
stations = session.query(Stations.name, Stations.station).all()

# %%
stations_df  = pd.DataFrame(stations,columns=["Station Name", "Station ID"])
stations_df
# Out:
#                              Station Name   Station ID
# 0                    WAIKIKI 717.2, HI US  USC00519397
# 1                    KANEOHE 838.1, HI US  USC00513117
# 2  KUALOA RANCH HEADQUARTERS 886.9, HI US  USC00514830
# 3                       PEARL CITY, HI US  USC00517948
# 4              UPPER WAHIAWA 874.3, HI US  USC00518838
# 5      WAIMANALO EXPERIMENTAL FARM, HI US  USC00519523
# 6                     WAIHEE 837.5, HI US  USC00519281
# 7       HONOLULU OBSERVATORY 702.2, HI US  USC00511918
# 8            MANOA LYON ARBO 785.2, HI US  USC00516128

# %%
stations_dict = stations_df.to_dict(orient='records')
stations_dict
# Out:
# [{'Station ID': 'USC00519397', 'Station Name': 'WAIKIKI 717.2, HI US'},
#  {'Station ID': 'USC00513117', 'Station Name': 'KANEOHE 838.1, HI US'},
#  {'Station ID': 'USC00514830',
#   'Station Name': 'KUALOA RANCH HEADQUARTERS 886.9, HI US'},
#  {'Station ID': 'USC00517948', 'Station Name': 'PEARL CITY, HI US'},
#  {'Station ID': 'USC00518838', 'Station Name': 'UPPER WAHIAWA 874.3, HI US'},
#  {'Station ID': 'USC00519523',
#   'Station Name': 'WAIMANALO EXPERIMENTAL FARM, HI US'},
#  {'Station ID': 'USC00519281', 'Station Name': 'WAIHEE 837.5, HI US'},
#  {'Station ID': 'USC00511918',
#   'Station Name': 'HONOLULU OBSERVATORY 702.2, HI US'},
#  {'Station ID': 'USC00516128', 'Station Name': 'MANOA LYON ARBO 785.2, HI US'}]

# %%
# Design a query to calculate the total number of stations.
station_count = session.query(Stations.id).count()
print ("Total Number of Stations are: "+ str(station_count))
# Out:
# Total Number of Stations are: 9

# %%
# Design a query to find the most active stations.
    # List the stations and observation counts in descending order
    # Which station has the highest number of observations?

# %%
# Query for finding the most active stations
# List the stations and observation counts in descending order
sel = [Measurements.station, func.count(Measurements.tobs)]
active_stations_data = session.query(*sel).group_by(Measurements.station).order_by(desc(func.count(Measurements.tobs))).all()
active_stations_data
# Out:
# [('USC00519281', 2772),
#  ('USC00513117', 2696),
#  ('USC00519397', 2685),
#  ('USC00519523', 2572),
#  ('USC00516128', 2484),
#  ('USC00514830', 1937),
#  ('USC00511918', 1932),
#  ('USC00517948', 683),
#  ('USC00518838', 342)]

# %%
print ("The station with the highest number of observations is: " + str(active_stations_data[0]))
# Out:
# The station with the highest number of observations is: ('USC00519281', 2772)

# %%
highest_station = active_stations_data[0][0] #Storing the highest station as a variable
highest_station
# Out:
# 'USC00519281'

# %%
initial_date #Printing the initial date
# Out:
# datetime.datetime(2016, 8, 23, 0, 0)

# %%
# Design a query to retrieve the last 12 months of temperature observation data (tobs).
# Filter by the station with the highest number of observations.
# Plot the results as a histogram with bins=12.

sel = [Measurements.tobs]
temperature_data = session.query(*sel).\
    filter(Measurements.date >= initial_date).\
    filter(Measurements.station == highest_station).all()

# Note-> initial_date was calcuated as 8/23/2016 by us earlier
# Note -> highest_station was calculated by us earlier

# %%
len(temperature_data) #Capturing the lenght of our dataset
# Out:
# 351

# %% [markdown]
# # Plot the results as a histogram with bins=12.

# %%
print (temperature_data)
# Out:
# [(77.0,), (80.0,), (80.0,), (75.0,), (73.0,), (78.0,), (77.0,), (78.0,), (80.0,), (80.0,), (78.0,), (78.0,), (78.0,), (73.0,), (74.0,), (80.0,), (79.0,), (77.0,), (80.0,), (76.0,), (79.0,), (75.0,), (79.0,), (78.0,), (79.0,), (78.0,), (78.0,), (76.0,), (74.0,), (77.0,), (78.0,), (79.0,), (79.0,), (77.0,), (80.0,), (78.0,), (78.0,), (78.0,), (77.0,), (79.0,), (79.0,), (79.0,), (79.0,), (75.0,), (76.0,), (73.0,), (72.0,), (71.0,), (77.0,), (79.0,), (78.0,), (79.0,), (77.0,), (79.0,), (77.0,), (78.0,), (78.0,), (78.0,), (78.0,), (77.0,), (74.0,), (75.0,), (76.0,), (73.0,), (76.0,), (74.0,), (77.0,), (76.0,), (76.0,), (74.0,), (75.0,), (75.0,), (75.0,), (75.0,), (71.0,), (63.0,), (70.0,), (68.0,), (67.0,), (77.0,), (74.0,), (77.0,), (76.0,), (76.0,), (75.0,), (76.0,), (75.0,), (73.0,), (75.0,), (73.0,), (75.0,), (74.0,), (75.0,), (74.0,), (75.0,), (73.0,), (75.0,), (73.0,), (73.0,), (74.0,), (70.0,), (72.0,), (70.0,), (67.0,), (67.0,), (69.0,), (70.0,), (68.0,), (69.0,), (69.0,), (66.0,), (65.0,), (68.0,), (62.0,), (75.0,), (70.0,), (69.0,), (76.0,), (76.0,), (74.0,), (73.0,), (71.0,), (74.0,), (74.0,), (72.0,), (71.0,), (72.0,), (74.0,), (69.
0,
#  76.0,
#  75.0,
#  73.0,
#  75.0,
#  73.0,
#  75.0,
#  74.0,
#  75.0,
#  74.0,
#  75.0,
#  73.0,
#  75.0,
#  73.0,
#  73.0,
#  74.0,
#  70.0,
#  72.0,
#  70.0,
#  67.0,
#  67.0,
#  69.0,
#  70.0,
#  68.0,
#  69.0,
#  69.0,
#  66.0,
#  65.0,
#  68.0,
#  62.0,
#  75.0,
#  70.0,
#  69.0,
#  76.0,
#  76.0,
#  74.0,
#  73.0,
#  71.0,
#  74.0,
#  74.0,
#  72.0,
#  71.0,
#  72.0,
#  74.0,
#  69.0,
#  67.0,
#  72.0,
#  70.0,
#  64.0,
#  63.0,
#  63.0,
#  62.0,
#  70.0,
#  70.0,
#  62.0,
#  62.0,
#  63.0,
#  65.0,
#  69.0,
#  77.0,
#  70.0,
#  74.0,
#  69.0,
#  72.0,
#  71.0,
#  69.0,
#  71.0,
#  71.0,
#  72.0,
#  72.0,
#  69.0,
#  70.0,
#  66.0,
#  65.0,
#  69.0,
#  68.0,
#  68.0,
#  68.0,
#  59.0,
#  60.0,
#  70.0,
#  73.0,
#  75.0,
#  64.0,
#  59.0,
#  59.0,
#  62.0,
#  68.0,
#  70.0,
#  73.0,
#  79.0,
#  75.0,
#  65.0,
#  70.0,
#  74.0,
#  70.0,
#  70.0,
#  71.0,
#  71.0,
#  71.0,
#  69.0,
#  61.0,
#  67.0,
#  65.0,
#  72.0,
#  71.0,
#  73.0,
#  72.0,
#  77.0,
#  73.0,
#  67.0,
#  62.0,
#  64.0,
#  67.0,
#  66.0,
#  81.0,
#  69.0,
#  66.0,
#  67.0,
#  69.0,
#  66.0,
#  68.0,
#  65.0,
#  74.0,
#  69.0,
#  72.0,
#  73.0,
#  72.0,
#  71.0,
#  76.0,
#  77.0,
#  76.0,
#  74.0,
#  68.0,
#  73.0,
#  71.0,
#  74.0,
#  75.0,
#  70.0,
#  67.0,
#  71.0,
#  67.0,
#  74.0,
#  77.0,
#  78.0,
#  67.0,
#  70.0,
#  69.0,
#  69.0,
#  74.0,
#  78.0,
#  71.0,
#  67.0,
#  68.0,
#  67.0,
#  76.0,
#  69.0,
#  72.0,
#  76.0,
#  68.0,
#  72.0,
#  74.0,
#  70.0,
#  67.0,
#  72.0,
#  60.0,
#  65.0,
#  75.0,
#  70.0,
#  75.0,
#  70.0,
#  79.0,
#  75.0,
#  70.0,
#  67.0,
#  74.0,
#  70.0,
#  75.0,
#  76.0,
#  77.0,
#  74.0,
#  74.0,
#  74.0,
#  69.0,
#  68.0,
#  76.0,
#  74.0,
#  71.0,
#  71.0,
#  74.0,
#  74.0,
#  74.0,
#  74.0,
#  80.0,
#  74.0,
#  72.0,
#  75.0,
#  80.0,
#  76.0,
#  76.0,
#  77.0,
#  75.0,
#  75.0,
#  75.0,
#  75.0,
#  72.0,
#  74.0,
#  74.0,
#  74.0,
#  76.0,
#  74.0,
#  75.0,
#  73.0,
#  79.0,
#  75.0,
#  72.0,
#  72.0,
#  74.0,
#  72.0,
#  72.0,
#  77.0,
#  71.0,
#  73.0,
#  76.0,
#  77.0,
#  76.0,
#  76.0,
#  79.0,
#  81.0,
#  76.0,
#  78.0,
#  77.0,
#  74.0,
#  75.0,
#  78.0,
#  78.0,
#  69.0,
#  72.0,
#  74.0,
#  74.0,
#  76.0,
#  80.0,
#  80.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  82.0,
#  75.0,
#  77.0,
#  75.0,
#  76.0,
#  81.0,
#  82.0,
#  81.0,
#  76.0,
#  77.0,
#  82.0,
#  83.0,
#  77.0,
#  77.0,
#  77.0,
#  76.0,
#  76.0,
#  79.0]

# %%
plt.hist(tobs_data, bins=12, label='tobs', color = 'lightcoral')
plt.xlabel("Temparture Observation Data")
plt.ylabel("Frequency")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Return a json list of Temperature Observations (tobs) for the previous year

# %%
# Query for retrieving last 12 months of precipitation data
# All precipitation data for last 12 months
sel = [Measurements.date, Measurements.prcp]

initial_date = format_latest_date - timedelta(days=365) # This will be start date from 12 months before final date of 8/23/17


prcp_data = session.query(*sel).\
    filter((Measurements.date >= initial_date)).all()
    
### END SOLUTION
prcp_data[:10]

# %% [markdown]
# # Code for Temperature Analysis

# %%
#Temperature Analysis
#Write a function called calc_temps that will accept a start date and end date in the format %Y-%m-%d and return the minimum, average, and maximum temperatures for that range of dates.
#Use the calc_temps function to calculate the min, avg, and max temperatures for your trip using the matching dates from the previous year (i.e. use "2017-01-01" if your trip start date was "2018-01-01")
#Plot the min, avg, and max temperature from your previous query as a bar chart.
#Use the average temperature as the bar height.
#Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr).

# %%
def calc_temp(start_date, end_date):
    Start_Date = dt.strptime(start_date, "%Y-%m-%d")
    Start_Date = Start_Date.replace(Start_Date.year - 1)
    End_Date = dt.strptime(end_date, "%Y-%m-%d")
    End_Date = End_Date.replace(End_Date.year - 1)
    
    #Collect all the dates between start date and end date
    delta = End_Date - Start_Date
    date_range = []
    for i in range(delta.days + 1):
        date_range.append(Start_Date + timedelta(days=i))
       
    #Converting to stings
    str_date_range = []
    for date in date_range:
        new_date = date.strftime("%Y-%m-%d")
        str_date_range.append(new_date)
       
   #Calculate Average Tempareure , Min and Maximum temperatures within the date range    
    temp_avg = session.query(func.avg(Measurements.tobs))\
              .filter(Measurements.date.in_(str_date_range))[0][0]
    temp_min = session.query(func.min(Measurements.tobs))\
              .filter(Measurements.date.in_(str_date_range))[0][0]
    temp_max = session.query(func.max(Measurements.tobs))\
              .filter(Measurements.date.in_(str_date_range))[0][0]
       
    return temp_avg, temp_min, temp_max

# %%
start_date = input("Please enter your trip's start date: ")
end_date = input ("Please enter your trip's end date: ")
# Out:
# Please enter your trip's start date: 2018-05-01
# Please enter your trip's end date: 2018-05-15

# %%
# Return a json list of the minimum temperature, the average temperature, and the max temperature for a given start or start-end range.

# %%
Trip_Output = calc_temp(start_date, end_date)
Trip_Output
# Out:
# (75.19753086419753, 65.0, 80.0)

# %%
tavg = Trip_Output[0]
tmin = Trip_Output[1]
tmax = Trip_Output[2]

# %%
Trip_Output_list = list(Trip_Output)

# %%
trip_output_df  = pd.DataFrame({"Minimum Temperature": [tmin], "Average Temperature":[tavg], "Maximum Temperature":[tmax]})
trip_output_df
# Out:
#    Average Temperature  Maximum Temperature  Minimum Temperature
# 0            75.197531                 80.0                 65.0

# %%
trip_output_dict  = {"Minimum Temperature": tmin, "Average Temperature":tavg, "Maximum Temperature":tmax}
trip_output_dict
# Out:
# {'Average Temperature': 75.19753086419753,
#  'Maximum Temperature': 80.0,
#  'Minimum Temperature': 65.0}

# %%
# Plot the min, avg, and max temperature from your previous query as a bar chart.

# Use the average temperature as the bar height.
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr).

# Plot Bar chart 
plt.figure(figsize=(2,5))
plt.bar(1,height=tavg, yerr=(tmax-tmin), width=0.0001, alpha=0.5)
plt.title("Trip Avg Temperature")
plt.xticks([])
plt.ylim(0,100)
plt.ylabel("Temp (F)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="200">

# %% [markdown]
# # Practice Code - Query Dates

# %%
# Total dates
session.query(func.count(Measurements.date)).all()

# %%
# Earliest Date
session.query(Measurements.date).order_by(Measurements.date).first()

# %%
# Latest Date
session.query(Measurements.date).order_by(Measurements.date.desc()).first()

# %%
# Query for 1 week before `2017-08-23` using the datetime library
query_date = dt.date(2017, 8, 23) - dt.timedelta(days=7)
print("Query Date: ", query_date)

# %%
session.query(Measurements.date, Measurements.station, Measurements.prcp, Measurements.tobs).\
      filter(Measurements.date == query_date).all()

# %% [markdown]
# # Practice Code Ends
